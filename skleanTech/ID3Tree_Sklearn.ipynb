# %%
# This should be roughly the content of the first code cell
import numpy as np
import random
np.random.seed(1337)
random.seed(1337)

# %%
from doctest import DocTestCase
import pandas as pd
import sklearn
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
#     Tree structure:
#     The results show that the tree created using sklearn is much deeper than the tree I created in problem 2.
#     This has to do with the type of data sklearn accepts, we have to use get_dummies to
#     convert categorical features to bunch of non categorical features,
#     and it makes the tree deeper.

# %% [markdown]
#     Error metrics:
#     The results predicted using the sklearn model are almost the
#     same as the results I predicted after deleting COUNTY and STATE in PROBLEM 2.

# %%
df1 = pd.read_csv("elections_clean.csv")
df = df1[['democrat', 'county', 'state', 'education', 'religion', 'ethnic_male','ethnic_female']]
#df.drop(columns=['county'], axis = 1, inplace = True)
df.dropna(inplace = True)
df
# Out:
# /var/folders/dz/ffb7x_vj5vl9758_4vqfvj3m0000gn/T/ipykernel_78875/3893859448.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)
#       democrat                             county state   education  \
# 0            0                       Sioux County    NE    Educated
# 1            1                     Baltimore city    MD    Educated
# 2            1                  Chittenden County    VT    Educated
# 3            0  Prince of Wales-Hyder Census Area    AK  Uneducated
# 4            0                   St. Johns County    FL    Educated
# ...        ...                                ...   ...         ...
# 3140         0                     Clinton County    MO    Educated
# 3141         0                       Union County    AR  Uneducated
# ...

# %%
target = 'democrat'
y = df[target]
df.drop([target], axis = 1, inplace = True)

X = pd.get_dummies(df)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
#print(one_hot_data)
# Out:
# /var/folders/dz/ffb7x_vj5vl9758_4vqfvj3m0000gn/T/ipykernel_78875/705639739.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop([target], axis = 1, inplace = True)

# %%
ID3Tree = DTC(criterion= 'entropy')
ID3Tree.fit(X_train, y_train)

predictions = ID3Tree.predict(X_test)
#print(y_test)
print("Accuracy (%):",metrics.accuracy_score(y_test, predictions)*100,"%")
# Out:
# Accuracy (%): 87.79193205944799 %

# %%
print(tree.export_text(ID3Tree))
# Out:
# |--- feature_1953 <= 0.50
# |   |--- feature_1926 <= 0.50
# |   |   |--- feature_1918 <= 0.50
# |   |   |   |--- feature_1937 <= 0.50
# |   |   |   |   |--- feature_1906 <= 0.50
# |   |   |   |   |   |--- feature_1206 <= 0.50
# |   |   |   |   |   |   |--- feature_89 <= 0.50
# |   |   |   |   |   |   |   |--- feature_1849 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_1247 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_784 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_811 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_811 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_784 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1247 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# ...
